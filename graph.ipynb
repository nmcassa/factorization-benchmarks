# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def generate_graph(data, title): 
    markers = ['^g-', 'vr-', '<b-', 'xy-','sb-']

    x = data.columns[1:]

    for cnt, item in enumerate(data['algo']):
        y = np.array(data.iloc[cnt, 1:])
        plt.plot(x, y, markers[cnt], label=data.iloc[cnt, 0])

    plt.yscale('log')
    plt.legend()
    plt.xlabel('Embedding Dimension d')
    plt.ylabel('Time (in ms)')
    plt.title(title)
    plt.grid()
    plt.show()

# %%
ml_data = pd.read_csv('ML.csv')

generate_graph(ml_data, "MovieLens 20M")

# %%
msd_data = pd.read_csv('MDS.csv')

generate_graph(msd_data, "Million Song Dataset")
